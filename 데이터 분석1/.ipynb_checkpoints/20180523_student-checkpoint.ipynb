# %% [markdown]
# # 안산시 고등학교 위치 시각화
# #### 경기도 공공데이터: "경기데이터드림"
# - https://data.gg.go.kr/portal/data/service/selectServicePage.do?page=1&rows=10&sortColumn=&sortDirection=&infId=WL5ESBLQR3R5E8CQOX4U23432290&infSeq=2&order=&searchWord=%EA%B3%A0%EB%93%B1%ED%95%99%EA%B5%90

# %%
# 필요 모듈 임포트
import numpy as np
import pandas as pd

# %%
# 데이터 로드
gg_highschool = pd.read_excel('졸업생의진로현황(고과정,고등학교).xls'
                             ,encoding='utf-8')
gg_highschool.head(1)
# Out:
#    기준년도  시군명  지역교육청명      지역명     학교명  학교급명 설립구분명 주야간명 제외여부 제외사유   ...     \
# 0  2017  가평군  경기도교육청  경기도 가평군  가평고등학교  고등학교    공립   주간    N  NaN   ...
#
#    진학합계(명)  진학비율(%)  취업남자수(명)  취업여자수(명)  취업합계(명)  취업비율(%)  기타남자수(명)  기타여자수(명)  \
# 0    252.0     82.6      11.0       8.0     19.0      6.2      22.0      12.0
#
#    기타합계(명)  기타비율(%)
# 0     34.0     11.1
#
# [1 rows x 25 columns]

# %%
# 안산 데이터만!
ansan_highschool = gg_highschool[gg_highschool["시군명"]=="안산시"]
ansan_highschool.head(1)
# Out:
#      기준년도  시군명  지역교육청명          지역명     학교명  학교급명 설립구분명 주야간명 제외여부 제외사유  \
# 225  2017  안산시  경기도교육청  경기도 안산시 단원구  원곡고등학교  고등학교    공립   주간    N  NaN
#
#       ...     진학합계(명)  진학비율(%)  취업남자수(명)  취업여자수(명)  취업합계(명)  취업비율(%)  \
# 225   ...       343.0     73.3       6.0       1.0      7.0      1.5
#
#      기타남자수(명)  기타여자수(명)  기타합계(명)  기타비율(%)
# 225      73.0      45.0    118.0     25.2
#
# [1 rows x 25 columns]

# %% [markdown]
# ### 고등학교 20곳의 주소를 가져와야 함.
# - [Google Maps Geocoding API]https://developers.google.com/maps/?hl=ko
# * 구글 맵스를 사용해서 고등학교의 주소, 위치(위도 좌표, 경도 좌표) 정보를 받아온다

# %%
import googlemaps

# %%
# https://developers.google.com/maps/documentation/geocoding/start?hl=ko
gmaps_key = "AIzaSyCwzl4fqWZUeU6JCnVayOSaFKBYbFuUXsA" # 자신의 key를 사용합니다.
gmaps = googlemaps.Client(key = gmaps_key)

# %%
gmaps.geocode('안산 광덕고', language='ko')
# Out:
# [{'address_components': [{'long_name': '２３６−３７',
#     'short_name': '２３６−３７',
#     'types': ['premise']},
#    {'long_name': '월피동',
#     'short_name': '월피동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '상록구',
#     'short_name': '상록구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '안산시',
#     'short_name': '안산시',
#     'types': ['locality', 'political']},
#    {'long_name': '경기도',
#     'short_name': '경기도',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '426-070',
#     'short_name': '426-070',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 경기도 안산시 상록구 월피동 236-37',
#   'geometry': {'location': {'lat': 37.3401712, 'lng': 126.8460443},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.3415201802915,
#      'lng': 126.8473932802915},
#     'southwest': {'lat': 37.3388222197085, 'lng': 126.8446953197085}}},
#   'place_id': 'ChIJvbqpZ2dvezUREG4i3pgVrag',
#   'types': ['establishment', 'point_of_interest', 'school']},
#  {'address_components': [{'long_name': '２７４',
#     'short_name': '２７４',
#     'types': ['premise']},
#    {'long_name': '월피동',
#     'short_name': '월피동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '상록구',
#     'short_name': '상록구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '안산시',
#     'short_name': '안산시',
#     'types': ['locality', 'political']},
#    {'long_name': '경기도',
#     'short_name': '경기도',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '426-070',
#     'short_name': '426-070',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 경기도 안산시 상록구 월피동 274',
#   'geometry': {'location': {'lat': 37.337144, 'lng': 126.846267},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.3384929802915,
#      'lng': 126.8476159802915},
#     'southwest': {'lat': 37.3357950197085, 'lng': 126.8449180197085}}},
#   'place_id': 'ChIJhYtw-WdvezURON6k7czl0bg',
#   'types': ['establishment', 'point_of_interest', 'school']}]

# %%
# 데이터 내 모든 고등학교의 주소 얻기
school_addreess = []
school_lat = []
school_lng = []

for name in ansan_highschool['학교명']: # 조금 전 작업한 school_name에서
    tmp = gmaps.geocode("안산 " + name, language='ko') # 경찰서이름을 넣고, geocode 정보를 가져와 tmp에 저장한다.
    school_addreess.append(tmp[0].get("formatted_address")) # tmp[0]번째의 'formatted_address'를 가져와 school_address에 저장한다.
    
    tmp_loc = tmp[0].get("geometry") # tmp[0]번째의 'geometry' 정보를 tmp_loc에 저장한다.

    school_lat.append(tmp_loc['location']['lat']) # tmp_loc의 'location' 부분의 'lat'를 school_lat에 추가한다.
    school_lng.append(tmp_loc['location']['lng']) # tmp_loc의 'location' 부분의 'lng'를 school_lng에 추가한다.
    
    print(name + ' --> ' + tmp[0].get("formatted_address")) # 검색한 이름과 추가된 정보를 --> 로 구분하여 표현해 준다.
# Out:
# 원곡고등학교 --> 대한민국 경기도 안산시 단원구 원곡본동 화랑로 15
# 선부고등학교 --> 대한민국 경기도 안산시 단원구 선부2동 990
# 신길고등학교 --> 대한민국 경기도 안산시 단원구 원곡동 신길로 45
# 광덕고등학교 --> 대한민국 경기도 안산시 상록구 월피동 236-37
# 명혜학교 --> 대한민국 경기도 안산시 상록구 사동 1273
# 안산동산고등학교 --> 대한민국 경기도 안산시 상록구 본오1동 충장로 56
# 대부고등학교 --> 대한민국 경기도 안산시 단원구 대부북동 697-6
# 양지고등학교 --> 대한민국 경기도 안산시 단원구 고잔동 713
# 한국선진학교 --> 대한민국 경기도 안산시 상록구 본오동 723-2
# 상록고등학교 --> 대한민국 경기도 안산시 상록구 본오3동 각골로4길 29
# 부곡고등학교 --> 대한민국 경기도 안산시 상록구 부곡동 446-3
# 초지고등학교 --> 대한민국 경기도 안산시 단원구 초지동 725-1
# 고잔고등학교 --> 대한민국 경기도 안산시 단원구 호수동 광덕2로 222
# 경안고등학교 --> 대한민국 경기도 안산시 단원구 고잔동 677
# 성포고등학교 --> 대한민국 경기도 안산시 상록구 성포동 충장로 538
#                      2016       5.0     13.0
#                      2017       0.0      0.0
#             단원고등학교   2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       7.0     17.0
#             대부고등학교   2015       7.0      8.0
#                      2016       2.0      4.0
#                      2017       3.0      4.0
#             선부고등학교   2015      19.0     35.0
#                      2016      62.0     79.0
#                      2017       0.0      0.0
#             신길고등학교   2015      38.0     87.0
#                      2016      23.0     67.0
#                      2017       2.0      4.0
#             안산강서고등학교 2015      10.0     20.0
#                      2016      12.0     24.0
#                      2017       4.0      5.0
#             양지고등학교   2015      11.0     23.0
#                      2016       4.0      8.0
#                      2017       5.0      9.0
#             원곡고등학교   2015       0.0      3.0
#                      2016       1.0     13.0
#                      2017       1.0      7.0
#             초지고등학교   2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
# 경기도 안산시 상록구 광덕고등학교   2015       3.0     53.0
#                      2016       7.0     29.0
#                      2017      22.0     42.0
#             명혜학교     2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
#             부곡고등학교   2015       0.0      0.0
#                      2016       1.0      1.0
#                      2017       1.0      3.0
#             상록고등학교   2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
#             성안고등학교   2015       1.0      2.0
#                      2016       0.0      0.0
#                      2017      10.0     40.0
#             성포고등학교   2015      30.0     65.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
#             송호고등학교   2015       0.0      0.0
#                      2016       3.0      8.0
#                      2017       0.0      0.0
#             안산고등학교   2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
#             안산동산고등학교 2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0
#             한국선진학교   2015       0.0      0.0
#                      2016       0.0      0.0
#                      2017       0.0      0.0

# %%
# 피벗 테이블  index=["기준년도", "지역명","학교명"], values=["졸업합계(명)","진학합계(명)","취업합계(명)","기타합계(명)"
pd.pivot_table(ansan_highschool, index=["기준년도", "지역명"], values=["졸업합계(명)","진학합계(명)","취업합계(명)","기타합계(명)"]
              , aggfunc = np.sum)
# Out:
#                   기타합계(명)  졸업합계(명)  진학합계(명)  취업합계(명)
# 기준년도 지역명
# 2015 경기도 안산시 단원구   1041.0   5221.0   4001.0    179.0
#      경기도 안산시 상록구    690.0   3407.0   2597.0    120.0
# 2016 경기도 안산시 단원구    573.0   4060.0   3273.0    214.0
#      경기도 안산시 상록구   1024.0   4023.0   2961.0     38.0
# 2017 경기도 안산시 단원구    713.0   3992.0   3218.0     61.0
#      경기도 안산시 상록구    963.0   3784.0   2736.0     85.0

# %%
# 피벗 테이블  index=["기준년도", "지역명","학교명"], values=["졸업합계(명)","진학합계(명)","취업합계(명)","기타합계(명)"
pd.pivot_table(ansan_highschool, index=["학교명"], values=["졸업합계(명)","진학합계(명)","취업합계(명)","기타합계(명)"])
# Out:
#              기타합계(명)     졸업합계(명)     진학합계(명)    취업합계(명)
# 학교명
# 경안고등학교    178.666667  588.666667  403.000000   7.000000
# 고잔고등학교     89.666667  553.666667  458.666667   5.333333
# 광덕고등학교     36.000000  350.333333  273.000000  41.333333
# 단원고등학교     67.333333  334.333333  261.333333   5.666667
# 대부고등학교     16.666667   51.333333   29.333333   5.333333
# 명혜학교        9.666667   13.333333    3.666667   0.000000
# 부곡고등학교     76.333333  261.000000  183.333333   1.333333
# 상록고등학교     94.000000  315.000000  221.000000   0.000000
# 선부고등학교     44.333333  392.666667  310.333333  38.000000
# 성안고등학교    141.333333  590.666667  435.333333  14.000000
# 성포고등학교     87.000000  499.333333  390.666667  21.666667
# 송호고등학교     73.000000  624.000000  548.333333   2.666667
# 신길고등학교     38.666667  362.666667  271.333333  52.666667
# 안산강서고등학교   45.333333  534.000000  472.333333  16.333333
# 안산고등학교    116.000000  421.000000  305.000000   0.000000
# 안산동산고등학교  246.666667  651.000000  404.333333   0.000000
# 양지고등학교     55.333333  506.000000  437.333333  13.333333
# 원곡고등학교    125.000000  516.666667  384.000000   7.666667
# 초지고등학교    114.666667  584.333333  469.666667   0.000000
# 한국선진학교     12.333333   12.333333    0.000000   0.000000

# %%
# 시각화 패키지 matplotlib과 seaborn 불러오기
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# 폰트 문제 해결하기
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
# 상관관계 플롯 y_vars=["진학합계(명)","취업합계(명)","기타합계(명)"], x_vars="졸업합계(명)"
sns.pairplot(ansan_highschool, y_vars=["진학합계(명)","취업합계(명)","기타합계(명)"], x_vars="졸업합계(명)")

# %%
# 박스 플롯 x="기준년도", y="진학비율(%)", hue="지역명"
plt.figure(figsize=(8,6))
sns.boxplot(x="기준년도", y="진학비율(%)", hue="지역명", data=ansan_highschool, palette="Set3") 
plt.show()

# %%
# 박스 플롯 x="기준년도", y="진학비율(%)", hue="설립구분명"
sns.boxplot(x="기준년도", y="진학비율(%)", hue="설립구분명", data=ansan_highschool, palette="Set1")

# %%
# 박스 플롯 x="기준년도", y="취업비율(%)", hue="지역명"
sns.boxplot(x="기준년도", y="취업비율(%)", hue="지역명", data=ansan_highschool, palette="Set2")

# %%
# 박스 플롯 x="기준년도", y="취업비율(%)", hue="설립구분명"
sns.boxplot(x="기준년도", y="취업비율(%)", hue="설립구분명", data=ansan_highschool, palette="Set1")

# %%
# 2017년도만 다뤄보자
ansan_highschool_2017 = ansan_highschool[ansan_highschool["기준년도"]==2017]
ansan_highschool_2017
# Out:
#           기준년도  시군명  지역교육청명          지역명  학교급명 설립구분명 주야간명 제외여부 제외사유  졸업남자수(명)  \
# 학교명
# 원곡고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     251.0
# 선부고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     176.0
# 신길고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     164.0
# 광덕고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     157.0
# 명혜학교      2017  안산시  경기도교육청  경기도 안산시 상록구  특수학교    사립   주간    N  NaN       6.0
# 안산동산고등학교  2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    사립   주간    N  NaN     291.0
# 대부고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN      24.0
# 양지고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     212.0
# 한국선진학교    2017  안산시     교육부  경기도 안산시 상록구  특수학교    국립   주간    N  NaN       9.0
# 상록고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     241.0
# 부곡고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     193.0
# 초지고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     263.0
# 고잔고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     284.0
# 경안고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    사립   주간    N  NaN     275.0
# 성포고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     224.0
# 성안고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     282.0
# 안산강서고등학교  2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    사립   주간    N  NaN     226.0
# 안산고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    사립   주간    N  NaN     199.0
# 단원고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     215.0
# 송호고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     289.0
#
#              ...      취업여자수(명)  취업합계(명)  취업비율(%)  기타남자수(명)  기타여자수(명)  기타합계(명)  \
# 학교명          ...
# 원곡고등학교       ...           1.0      7.0      1.5      73.0      45.0    118.0
# 선부고등학교       ...           0.0      0.0      0.0      55.0      23.0     78.0
# 신길고등학교       ...           2.0      4.0      1.3      23.0      16.0     39.0
# 광덕고등학교       ...          22.0     42.0     13.2      32.0      14.0     46.0
# 명혜학교         ...           0.0      0.0      0.0       4.0       4.0      8.0
# 안산동산고등학교     ...           0.0      0.0      0.0     130.0     148.0    278.0
# 대부고등학교       ...           3.0      4.0      8.3      14.0       2.0     16.0
# 양지고등학교       ...           5.0      9.0      2.2       6.0       4.0     10.0
# 한국선진학교       ...           0.0      0.0      0.0       9.0       4.0     13.0
# 상록고등학교       ...           0.0      0.0      0.0      77.0      63.0    140.0
# 부곡고등학교       ...           1.0      3.0      0.8      64.0      41.0    105.0
# 초지고등학교       ...           0.0      0.0      0.0      62.0      43.0    105.0
# 고잔고등학교       ...           0.0      0.0      0.0      78.0      67.0    145.0
# 경안고등학교       ...           0.0     15.0      2.8      70.0      45.0    115.0
# 성포고등학교       ...           0.0      0.0      0.0      52.0      45.0     97.0
# 성안고등학교       ...          10.0     40.0      7.5      63.0      24.0     87.0
da3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           기준년도  시군명  지역교육청명          지역명  학교급명 설립구분명 주야간명 제외여부 제외사유  졸업남자수(명)  \
# 학교명
# 안산동산고등학교  2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    사립   주간    N  NaN     291.0
# 송호고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     289.0
# 고잔고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    공립   주간    N  NaN     284.0
# 경안고등학교    2017  안산시  경기도교육청  경기도 안산시 단원구  고등학교    사립   주간    N  NaN     275.0
# 성안고등학교    2017  안산시  경기도교육청  경기도 안산시 상록구  고등학교    공립   주간    N  NaN     282.0
#
#              ...      취업합계(명)  취업비율(%)  기타남자수(명)  기타여자수(명)  기타합계(명)  기타비율(%)  \
# 학교명          ...
# 안산동산고등학교     ...          0.0      0.0     130.0     148.0    278.0     42.7
# 송호고등학교       ...          0.0      0.0      33.0      38.0     71.0     12.2
# 고잔고등학교       ...          0.0      0.0      78.0      67.0    145.0     26.5
# 경안고등학교       ...         15.0      2.8      70.0      45.0    115.0     21.3
# 성안고등학교       ...         40.0      7.5      63.0      24.0     87.0     16.2
#
#                                      주소        lat         lng          졸업
# 학교명
# 안산동산고등학교   대한민국 경기도 안산시 상록구 본오1동 충장로 56  37.286857  126.858570  100.000000
# 송호고등학교          대한민국 경기도 안산시 상록구 이동 665  37.310786  126.845545   89.093702
# 고잔고등학교    대한민국 경기도 안산시 단원구 호수동 광덕2로 222  37.308717  126.835267   84.024578
# 경안고등학교         대한민국 경기도 안산시 단원구 고잔동 677  37.326062  126.833490   83.102919
# 성안고등학교         대한민국 경기도 안산시 상록구 사동 1582  37.302509  126.842351   82.334869
#
# [5 rows x 28 columns]

# %%
# 졸업학생 수의 상대적 비율로 정렬
target_col = ["진학비율(%)", '취업비율(%)','기타비율(%)','졸업']
plt.figure(figsize = (10, 10))
sns.heatmap(ansan_highschool_2017_sort[target_col],annot=True,fmt = 'f',linewidths=5, cmap = 'RdPu')
plt.show()

# %% [markdown]
# ## 시각화

# %%
# 한국 지도 형태 가져오기
import folium
import json
geo_path = 'skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.303431, 126.8357822], zoom_start=12)
                 
for n in ansan_highschool_2017_sort.index:
    folium.Marker([ansan_highschool_2017_sort['lat'][n], 
                   ansan_highschool_2017_sort['lng'][n]]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 검거에 적당한 값(10)을 곱해서 원 넓이를 정하고, 경찰서의 검거율을 원의 넓이로 표현한다.
map = folium.Map(location=[37.303431, 126.8357822], zoom_start=12)

for n in ansan_highschool_2017_sort.index:
    folium.CircleMarker([ansan_highschool_2017_sort['lat'][n], ansan_highschool_2017_sort['lng'][n]], 
                        radius = ansan_highschool_2017_sort['취업비율(%)'][n]*10, 
                        color='#3186cc', fill_color='#3186cc', fill=True).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 검거에 적당한 값(10)을 곱해서 원 넓이를 정하고, 경찰서의 검거율을 원의 넓이로 표현한다.
map = folium.Map(location=[37.303431, 126.8357822], zoom_start=12)

for n in ansan_highschool_2017_sort.index:
    folium.CircleMarker([ansan_highschool_2017_sort['lat'][n], ansan_highschool_2017_sort['lng'][n]], 
                        radius = ansan_highschool_2017_sort['진학비율(%)'][n]*0.4, 
                        color='#3186cc', fill_color='#3186cc', fill=True).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
